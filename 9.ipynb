# %% [markdown]
# The mean and variance of both the Binomial and Poisson distributions are intrinsically linked to their parameters, but the nature of these relationships differs between the two distributions.
#
# Binomial Distribution
# In a Binomial distribution, the mean and variance are determined by two parameters:
# �
# n (number of trials) and
# �
# p (probability of success in each trial). The relationships are as follows:
#
# Mean (
# �
# μ): The mean of a Binomial distribution is given by the product of the number of trials and the probability of success.
# �
# =
# �
# �
# μ=np
#
# Variance (
# �
# 2
# σ
# 2
#  ): The variance is given by the product of the mean and the probability of failure (which is
# 1
# −
# �
# 1−p).
# �
# 2
# =
# �
# �
# (
# 1
# −
# �
# )
# σ
# 2
#  =np(1−p)
#
# This reflects that in a Binomial distribution, as the number of trials increases, or as the probability of success varies, both the mean and the variance change.
#
# Poisson Distribution
# The Poisson distribution is characterized by a single parameter
# �
# λ (lambda), which is both the mean and the variance of the distribution:
#
# Mean (
# �
# μ): The mean of a Poisson distribution is
# �
# λ.
# �
# =
# �
# μ=λ
#
# Variance (
# �
# 2
# σ
# 2
#  ): The variance is also
# �
# λ.
# �
# 2
# =
# �
# σ
# 2
#  =λ
#
# In the case of the Poisson distribution, the mean and variance are equal. This distribution is often used to model the number of times an event occurs in a fixed interval of time or space, under the assumption that these events occur with a known constant mean rate and independently of the time since the last event.
#
# Summary
# In a Binomial distribution, the mean and variance are linked to the number of trials and the probability of success, with the variance being dependent on both the mean and the probability of success.
# In a Poisson distribution, the mean and variance are equal and are both described by the same single parameter,
# �
# λ.
