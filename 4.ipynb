# %% [markdown]
# The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials, each with the same probability of success. The properties of the binomial distribution include:
#
# Fixed Number of Trials (n): The experiment consists of a fixed number,
# �
# n, of identical and independent trials.
#
# Two Possible Outcomes: Each trial results in one of two outcomes - success or failure. This is often referred to as a Bernoulli trial.
#
# Constant Probability of Success (p): The probability of success, denoted by
# �
# p, remains constant for each trial. The probability of failure is
# �
# =
# 1
# −
# �
# q=1−p.
#
# Independence of Trials: The outcome of any trial does not affect the outcome of the other trials.
#
# The Binomial Formula: The probability of observing exactly
# �
# k successes in
# �
# n trials is given by the binomial formula:
# �
# (
# �
# =
# �
# )
# =
# (
# �
# �
# )
# �
# �
# (
# 1
# −
# �
# )
# �
# −
# �
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# where
# (
# �
# �
# )
# (
# k
# n
# ​
#  ) is the binomial coefficient, calculated as
# �
# !
# �
# !
# (
# �
# −
# �
# )
# !
# k!(n−k)!
# n!
# ​
#  .
#
# Mean and Variance: The mean (expected value) of a binomial distribution is
# �
# =
# �
# �
# μ=np, and the variance is
# �
# 2
# =
# �
# �
# (
# 1
# −
# �
# )
# σ
# 2
#  =np(1−p).
#
# Examples of Binomial Distribution
# Quality Control (Defective Products): Suppose a factory produces light bulbs, and each bulb has a 2% probability of being defective. If you randomly select 100 bulbs, the probability of finding a specific number of defective bulbs (say, 3 defective bulbs) follows a binomial distribution. Here,
# �
# =
# 100
# n=100,
# �
# =
# 3
# k=3, and
# �
# =
# 0.02
# p=0.02.
#
# Drug Efficacy in Clinical Trials: In a clinical trial for a new medication, each participant has a probability
# �
# p of showing improvement after receiving the treatment. If 50 people participate in the trial, the number of people showing improvement follows a binomial distribution. For example, if
# �
# =
# 0.7
# p=0.7 and
# �
# =
# 50
# n=50, one might want to calculate the probability of exactly 40 participants showing improvement.
