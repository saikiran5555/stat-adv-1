# %% [markdown]
# The Binomial and Poisson distributions are both discrete probability distributions, but they are used in different situations and have distinct properties:
#
# Binomial Distribution
# Definition: The Binomial distribution models the number of successes in a fixed number of independent trials.
#
# Parameters:
#
# �
# n: The number of trials.
# �
# p: The probability of success on each trial.
# Use Cases: It's used when:
#
# There is a fixed number of trials (
# �
# n).
# Each trial has only two outcomes (success or failure).
# The probability of success (
# �
# p) is the same for each trial.
# Trials are independent of one another.
# Probability Mass Function:
# �
# (
# �
# =
# �
# )
# =
# (
# �
# �
# )
# �
# �
# (
# 1
# −
# �
# )
# �
# −
# �
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# where
# �
# X is the number of successes in
# �
# n trials.
#
# Mean and Variance:
#
# Mean:
# �
# �
# np
# Variance:
# �
# �
# (
# 1
# −
# �
# )
# np(1−p)
# Poisson Distribution
# Definition: The Poisson distribution models the number of events occurring in a fixed interval of time or space, given that these events occur with a known constant mean rate and independently of the time since the last event.
#
# Parameters:
#
# �
# λ: The average number of events in an interval (the rate).
# Use Cases: It's used when:
#
# You're counting the number of events in a fixed interval.
# The events occur independently.
# The average rate (
# �
# λ) is constant.
# Two events cannot occur at exactly the same instant.
# Probability Mass Function:
# �
# (
# �
# =
# �
# )
# =
# �
# �
# �
# −
# �
# �
# !
# P(X=k)=
# k!
# λ
# k
#  e
# −λ
#
# ​
#
# where
# �
# X is the number of events.
#
# Mean and Variance:
#
# Mean:
# �
# λ
# Variance:
# �
# λ
# Key Differences
# Number of Trials vs. Time/Space Interval: The Binomial distribution is used for a fixed number of trials, whereas the Poisson distribution is used for events occurring over a continuous interval (time or space).
#
# Probability of Success vs. Rate of Occurrence: In the Binomial distribution, you have the probability of success for each trial, while in the Poisson distribution, you have an average rate of events per interval.
#
# Variance: In a Binomial distribution, the variance depends on both the probability of success and the number of trials, whereas in a Poisson distribution, the mean and variance are equal (both are
# �
# λ).
#
# Limiting Case: The Poisson distribution can be a limiting case of the Binomial distribution. If the number of trials
# �
# n goes to infinity, and the probability of success
# �
# p goes to zero in such a way that
# �
# �
# =
# �
# np=λ remains constant, the Binomial distribution approaches the Poisson distribution.
